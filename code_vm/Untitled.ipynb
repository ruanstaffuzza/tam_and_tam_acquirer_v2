# %%
from group_tam_id import (
    assign_group_ids,
    open_ton, load_to_gbq, create_doc_final, open_init_data,
    execute_with_context,
    init_group_id, 
    deal_merged_places, 
    deal_unmerged_places, 
    choose_prefered_document, 
    create_agrupamento_inspecao, 
    grouped_subs_asterisk, 
    final_ajustes)

# %%
import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import os

import time

from projectutils import read_data 
import sys

# %%
def execute(func, df, display_flag=True, verbose=True, LEVEL_GROUP=None, use_level=False, **kwargs):
    """
    Executes a given function on the DataFrame, optionally displays the result, and shows execution time.

    Parameters:
    - func: The processing function to execute. It should accept a DataFrame and return a DataFrame.
    - df: The DataFrame to process.
    - display_flag: Boolean flag indicating whether to display the DataFrame after processing.
    - verbose: Boolean flag indicating whether to print execution details.
    - LEVEL_GROUP: Optional parameter to pass a level group to the function.
    - use_level: Boolean flag indicating whether to use the LEVEL_GROUP parameter.
    - **kwargs: Additional keyword arguments to pass to the function.

    Returns:
    - The processed DataFrame.
    """

    start_time = time.time()  # Start timing before function execution
  

    if verbose:
        print(f'_______________\nExecuting function {func.__name__}...')

    if use_level:
        df = func(df, LEVEL_GROUP=LEVEL_GROUP, **kwargs)
    else:
        df = func(df, **kwargs)

    end_time = time.time()  # End timing after function execution
    execution_time = end_time - start_time  # Calculate execution time

    if verbose:
        print(f'Function {func.__name__} executed successfully in {execution_time:.2f} seconds.')
    
    
      
    if 'group_id' in df.columns:
        s = df['group_id'].str.len()
        print(f'Result Max group id size: {s.max()}')
        
        display(df.groupby('group_id').agg({
            #'group_id': 'nunique',
            'merchant_market_hierarchy_id': 'nunique'
        }).max())
        
        
    if 'group_id_index' in df.columns:
        sizes = df.groupby('group_id_index').ngroups
        print(f'qtd names group id: {sizes}')
        
    
    if 'group_id' in df.columns:
        #sizes = df['group_id_index'].value_counts().values[0]
        #print(f'qtd names group id: {sizes}')
        #print('Group ID in cols')
        big_group = df['group_id'].value_counts().index[0]
        #display(df[df['group_id']==big_group])
    
    #if 'group_id' in df.columns: print(f'Number of groups: {df["group_id"].nunique()}')
    
    if display_flag:
        display(df)
    return df


def execute_with_context(LEVEL_GROUP, display_flag=False, verbose=False):
    import inspect
    def execute_context(func, df, **kwargs):
        # Check if 'LEVEL_GROUP' is in the function's parameters
        params = inspect.signature(func).parameters
        if 'LEVEL_GROUP' in params:
            # If 'LEVEL_GROUP' is a parameter, pass it along with 'df'
            result = execute(func, df, display_flag=display_flag, verbose=verbose, LEVEL_GROUP=LEVEL_GROUP,
                             use_level=True, **kwargs)
        else:
            # If 'LEVEL_GROUP' is not a parameter, call the function without it
            result = execute(func, df, display_flag=display_flag, verbose=verbose, use_level=False, **kwargs)
        return result
    return execute_context

# %%
df = pd.read_parquet('data/main_data.parquet')

# %%
s = df[['nome_master', 'cod_muni', 'nome_muni', 'uf']].value_counts()

# %%
s[(s>10) & (s<20)].sample(20)
# Out:
# nome_master          cod_muni  nome_muni             uf
# DIVINOPOLIS          3122306   Divinópolis           MG    11
# MARIAEDUARDA         4314902   Porto Alegre          RS    16
# RESTAURANTE          4104808   Cascavel              PR    13
# AUTOPOSTOCINCOESTRE  5300108   Brasília              DF    15
# CASASBAHIA           3509502   Campinas              SP    11
# DROGASIL             3548500   Santos                SP    13
# ALINEMODAS           3550308   São Paulo             SP    14
# DROGASIL             1721000   Palmas                TO    14
# DISTRIBUIDORA        2933307   Vitória da Conquista  BA    13
# ODONTOCOMPANY        4106902   Curitiba              PR    18
# WALLACE              3550308   São Paulo             SP    13
# ODONTOLOGIA          5208707   Goiânia               GO    13
# ANACLAUDIA           1302603   Manaus                AM    16
# MERCADO              2910800   Feira de Santana      BA    11
# JOSEFERNANDES        3550308   São Paulo             SP    14
# TALITADASILVA        3550308   São Paulo             SP    13
# ANTONIOJOSE          2304400   Fortaleza             CE    14
# SABRINA              3304557   Rio de Janeiro        RJ    12
# EMPORIO              3170206   Uberlândia            MG    11
# MERCEARIAEADEGA      3550308   São Paulo             SP    15
# dtype: int64

# %%
df = pd.read_parquet('data/intermediary/part_18.parquet')

# %%
df
# Out:
#         subs_asterisk                    nome_master  nome_muni  uf  \
# 0               SumUp                        REYTECH  São Paulo  SP
# 1               SumUp                   APPSERVIDORE  São Paulo  SP
# 2               SumUp                    JOSEWILSONP  São Paulo  SP
# 3               SumUp                      MARIAARTS  São Paulo  SP
# 4               SumUp                   CANILBUTDOGG  São Paulo  SP
# ...               ...                            ...        ...  ..
# 1334900           Ton  CLINICAODONTOLOGIADENISEFERES  São Paulo  SP
# 1334901           Ton                  POINTDOCOYOTE  São Paulo  SP
# 1334902           Ton             ANGELICADAMOTALIMA  São Paulo  SP
# 1334903           Ton         BRUNACECCHETTIESTETICA  São Paulo  SP
# 1334904           Ton              DANTILANDIARACOES  São Paulo  SP
#
#                  cpf cpf_brasil  qtd_cpfs  qtd_cnpjs            cnpj  \
# 0               None       None      <NA>          1  55288394000117
# 1               None       None      <NA>       <NA>            None
# 2        17782026830       None        26         10  20701303000149
# 3               None       None      <NA>       <NA>            None
# 4               None       None      <NA>       <NA>            None
# ...              ...        ...       ...        ...             ...
# 1334900         None       None      <NA>       <NA>  03670613000124
# 1334901  16154481870       None      <NA>       <NA>            None
# 1334902  44972567821       None      <NA>       <NA>            None
# 1334903  39824084827       None      <NA>       <NA>            None
# 1334904         None       None      <NA>       <NA>  54369975000110
#
#         numero_inicio  cod_muni merchant_tax_id  mmhid_merge  \
# 0                None   3550308            None         <NA>
# 1                None   3550308            None         <NA>
# 2                None   3550308            None         <NA>
# 3                None   3550308            None         <NA>
# 4                None   3550308            None         <NA>
# ...               ...       ...             ...          ...
# 1334900          None   3550308            None         <NA>
# 1334901          None   3550308            None         <NA>
# 1334902          None   3550308            None         <NA>
# 1334903          None   3550308            None         <NA>
# 1334904          None   3550308            None         <NA>
#
#          merchant_market_hierarchy_id     id_ton  \
# 0                                <NA>        NaN
# 1                                <NA>        NaN
# 2                                <NA>        NaN
# 3                                <NA>        NaN
# 4                                <NA>        NaN
# ...                               ...        ...
# 1334900                          <NA>  1818529.0
# 1334901                          <NA>  1818530.0
# 1334902                          <NA>  1818554.0
# 1334903                          <NA>  1818555.0
# 1334904                          <NA>  1818566.0
#
#                                  nome_ton  inicio  \
# 0                                    None  REYTEC
# 1                                    None  APPSER
# 2                                    None  JOSEWI
# 3                                    None  MARIAA
# 4                                    None  CANILB
# ...                                   ...     ...
# 1334900  CLINICA ODONTOLOGIA DENISE FERES  CLINIC
# 1334901                   POINT DO COYOTE  POINTD
# 1334902             ANGELICA DA MOTA LIMA  ANGELI
# 1334903          BRUNA CECCHETTI ESTETICA  BRUNAC
# 1334904                DANTILANDIA RACOES  DANTIL
#
#                          resultado_names  \
# 0                              [REYTECH]
# 1                         [APPSERVIDORE]
# 2                          [JOSEWILSONP]
# 3                            [MARIAARTS]
# 4                         [CANILBUTDOGG]
# ...                                  ...
# 1334900  [CLINICAODONTOLOGIADENISEFERES]
# 1334901                  [POINTDOCOYOTE]
# 1334902             [ANGELICADAMOTALIMA]
# 1334903         [BRUNACECCHETTIESTETICA]
# 1334904              [DANTILANDIARACOES]
#
#                                         agrupamento_nome_1 _merge
# 0                                           REYTECH3550308   both
# 1                                      APPSERVIDORE3550308   both
# 2                     JOSEWILSONP, JOSEWILSONPEGADO3550308   both
# 3                                         MARIAARTS3550308   both
# 4                                      CANILBUTDOGG3550308   both
# ...                                                    ...    ...
# 1334900  CLINICAODONTOLOGIA, CLINICAODONTOLOGIADENISEFE...   both
# 1334901                               POINTDOCOYOTE3550308   both
# 1334902                          ANGELICADAMOTALIMA3550308   both
# 1334903                      BRUNACECCHETTIESTETICA3550308   both
# 1334904                           DANTILANDIARACOES3550308   both
#
# [1334905 rows x 20 columns]

# %%
def main_data_treat_muni(df, file_name):

    """
    Main function to process data with options to display intermediate DataFrames and print verbose messages.

    Parameters:
    - read_data_func: Function to read initial data.
    - display_flag: Boolean flag indicating whether to display the DataFrame after each processing step.
    - verbose: Boolean flag indicating whether to print verbose messages during processing.
    """
    display_flag=False
    
    len_df = len(df)
    
    #if len_df> 100000:
    #    verbose = True
    #else:
    #    verbose = False
    verbose = True
    LEVEL_GROUP = ['cod_muni']
    
    
    print(f'Starting main data treat for file {file_name}, with size {len(df)}')

    start = time.time()
    execute_ctx = execute_with_context(LEVEL_GROUP, display_flag=display_flag, verbose=verbose)

    df = execute_ctx(init_group_id, df)
    #df = execute_ctx(deal_unmerged_places, df)
    #df = execute_ctx(deal_merged_places, df)
    
    #df = execute_ctx(choose_prefered_document, df)
    #df = execute_ctx(create_agrupamento_inspecao, df)
    #df = execute_ctx(grouped_subs_asterisk, df)
    #df = execute_ctx(final_ajustes, df)
    #df = execute_ctx(create_doc_final, df)
    
    print(f'Main data treat Execution time file {file_name}: {time.time() - start:.2f} seconds')
    return df

# %%
df = main_data_treat_muni(df, 'teste SP')
# Out:
# Starting main data treat for file teste SP, with size 1334905
# _______________
# Executing function init_group_id...
# Function init_group_id executed successfully in 15.47 seconds.
# Result Max group id size: 115
# merchant_market_hierarchy_id    472
# dtype: int64
# Main data treat Execution time file teste SP: 20.90 seconds

# %%
def deal_unmerged_places(df, LEVEL_GROUP):
    df = df.copy()

    df['mmhid_places'] = df['mmhid_merge'].apply(lambda x: str(x) if not pd.isna(x) else np.nan) #deal with nan in Int
    df['new_id'] = np.arange(df.shape[0])
    df.loc[df['subs_asterisk']=='Ton', 'mmhid_places'] = 'Ton' + df['id_ton'].astype(str)
    df.loc[df['mmhid_places'].isnull(), 'mmhid_places'] = 'created' + df['new_id'].astype(str)

    #df['muni'] =  df[LEVEL_GROUP].astype(str).apply(lambda x: ' '.join(x))

    if len(LEVEL_GROUP)>1:
        df['mmhid_places'] = df['mmhid_places'] + ' - ' + df[LEVEL_GROUP].astype(str).apply(lambda x: '|'.join(x), axis=1)#df['muni']
    elif len(LEVEL_GROUP)==1:
        df['mmhid_places'] = df['mmhid_places'] + ' - ' + df[LEVEL_GROUP[0]].astype(str)
        
    df = assign_group_ids(df, ['group_id'], final_col='group_id_idx1')
        
    df['tam_group1'] = df.groupby('group_id_idx1')['nome_master'].transform('count')


    df = assign_group_ids(df, ['group_id', 'mmhid_places'], final_col='group_id_idx2')
    
    df['tam_group2'] = df.groupby('group_id_idx2')['nome_master'].transform('count')
    
    #df_grouped = df.copy()
    # SPLIT group_id by | . Get first element
    #df_grouped['group_id'] = df_grouped['group_id'].str.split('|').apply(lambda x: x[0])

    # concat group_id with group_id_index
    #df_grouped = df_grouped.groupby(['group_id_index'], as_index=False)['group_id'].apply(lambda x: list(x.dropna().unique()))
    #df_grouped = df_grouped.groupby(['group_id_index'], as_index=False)['group_id'].apply(lambda x: list(x.dropna().unique()))
    #df_grouped = df_grouped[['group_id_index', 'group_id']].drop_duplicates().groupby('group_id_index', as_index=False).head(10)
    
    #df_grouped = df_grouped.groupby(['group_id_index'], as_index=False)['group_id'].apply(lambda x: ', '.join(x))

    #df = df.drop(columns=['group_id', 'mmhid_places', 'new_id', 'id_ton'])
    #df = df.merge(df_grouped, on='group_id_index', how='left')

    #df = df.drop(columns=['group_id_index'])
    return df

df = deal_unmerged_places(df, LEVEL_GROUP=['cod_muni'])
#df4['len_resultado'] = df4.groupby('group_id_index')['nome_master'].transform('count')
#df4[df4['len_resultado']>1000]['agrupamento_nome_1'].unique()

# %%
def deal_merged_places(df, LEVEL_GROUP):
    df = df.copy()

    
    df['mmhid_places'] = df.loc[df['subs_asterisk'].isin(OUTROS), 'merchant_market_hierarchy_id']

    df_grouped = df.copy()

    level_group2 = ['group_id_idx2']
    
    df_grouped = df_grouped[df_grouped['mmhid_places'].notnull()]
    df_grouped = df_grouped[LEVEL_GROUP + level_group2 +  ['mmhid_places']].drop_duplicates()
    # Group by the specified columns and aggregate
    df_grouped = df_grouped.groupby(LEVEL_GROUP + level_group2).agg(
        unique_mmhid_places=('mmhid_places', 'first'),
        nunique_mmhid_places=('mmhid_places', 'nunique')
    ).reset_index()

    df = df.merge(df_grouped, on=LEVEL_GROUP + level_group2, how='left')
    
    df['group_id_idx3'] = df['group_id_idx2']
    

    df.loc[(df['nunique_mmhid_places']>1)
           & (df['subs_asterisk'].isin(OUTROS))
           , 'group_id_idx3'] = df['group_id_idx3'].astype(str) + ' - ' + df['mmhid_places'].astype(str)
    
    df.loc[(df['nunique_mmhid_places']>1)
           & (~df['subs_asterisk'].isin(OUTROS))
           , 'group_id_idx3'] = df['group_id_idx3'].astype(str) + ' - ' + df['unique_mmhid_places'].astype(str)

    
    df = assign_group_ids(df, ['group_id_idx3'], final_col='group_id_idx3')
    
    df = df.drop(columns=['mmhid_places', 'unique_mmhid_places', 'nunique_mmhid_places'])
    df['tam_group3'] = df.groupby('group_id_idx3')['nome_master'].transform('count')
    
    return df

# %%
OUTROS = ['Outros', 'Outros_Pags', 'Outros_SumUp']
df = deal_merged_places(df, LEVEL_GROUP=['cod_muni'])

# %%
df.columns
# Out:
# Index(['subs_asterisk', 'nome_master', 'nome_muni', 'uf', 'cpf', 'cpf_brasil',
#        'qtd_cpfs', 'qtd_cnpjs', 'cnpj', 'numero_inicio', 'cod_muni',
#        'merchant_tax_id', 'mmhid_merge', 'merchant_market_hierarchy_id',
#        'id_ton', 'nome_ton', 'inicio', 'grouped_names', 'agrupamento_nome_1',
#        '_merge', 'group_id', 'new_id', 'group_id_idx1', 'tam_group1',
#        'group_id_idx2', 'tam_group2', 'group_id_idx3', 'tam_group3'],
#       dtype='object')

# %%
nome = 'RESTAURANTEYAMASU'

def show_dataframe(df, nome, gid):
    tamg = f'tam_group{gnumber}'
    
    grupo = df[df['nome_master']==nome][gid].values[0]
    return df[df[gid]==grupo][['subs_asterisk', 'nome_master', 'merchant_tax_id', 'mmhid_merge', 'agrupamento_nome_1']]	

show_dataframe(df, nome=nome, gid = 'group_id_idx1')#[['mmhid_merge', 'merchant_market_hierarchy_id']].value_counts()
# Out:
#        subs_asterisk           nome_master merchant_tax_id  mmhid_merge  \
# 1855           Ifood     RESTAURANTEYAMASU            None         <NA>
# 257737        Outros  RESTAURANTEYAMASUSHI  29790794000116    505114550
#
#                                     agrupamento_nome_1
# 1855    RESTAURANTEYAMASU, RESTAURANTEYAMASUSHI3550308
# 257737  RESTAURANTEYAMASU, RESTAURANTEYAMASUSHI3550308

# %%
df.columns
# Out:
# Index(['subs_asterisk', 'nome_master', 'nome_muni', 'uf', 'cpf', 'cpf_brasil',
#        'qtd_cpfs', 'qtd_cnpjs', 'cnpj', 'numero_inicio', 'cod_muni',
#        'merchant_tax_id', 'mmhid_merge', 'merchant_market_hierarchy_id',
#        'id_ton', 'nome_ton', 'inicio', 'grouped_names', 'agrupamento_nome_1',
#        '_merge', 'group_id', 'new_id', 'group_id_idx1', 'tam_group1',
#        'group_id_idx2', 'tam_group2', 'group_id_idx3', 'tam_group3'],
#       dtype='object')

# %%
show_dataframe(df, nome='RESTAURANTEYAMASUSHI', gid = 'mmhid_merge')
# Out:
#        subs_asterisk           nome_master merchant_tax_id  mmhid_merge  \
# 8364          Outros           RESTAURANTE  29790794000116    505114550
# 257737        Outros  RESTAURANTEYAMASUSHI  29790794000116    505114550
#
#                                     agrupamento_nome_1
# 8364        RESTAURANTE, RESTAURANTE041946898603550308
# 257737  RESTAURANTEYAMASU, RESTAURANTEYAMASUSHI3550308

# %%
s = show_dataframe(df, nome='RESTAURANTE', gid = 'group_id_idx1')
s = s[s['mmhid_merge'].notnull()]
s
#[['mmhid_merge', 'merchant_market_hierarchy_id']].value_counts()
# Out:
#      subs_asterisk  nome_master merchant_tax_id  mmhid_merge  \
# 8339        Outros  RESTAURANTE  36589509000169    647431069
# 8340        Outros  RESTAURANTE  45663819000681    815781288
# 8341        Outros  RESTAURANTE                    866201937
# 8342        Outros  RESTAURANTE                    799200892
# 8343        Outros  RESTAURANTE                    763948377
# ...            ...          ...             ...          ...
# 8518   Outros_Pags  RESTAURANTE  41327703000106    715575740
# 8519   Outros_Pags  RESTAURANTE  46738754000144    565315603
# 8520   Outros_Pags  RESTAURANTE  28200757000148    847270011
# 8521   Outros_Pags  RESTAURANTE  47687834000180    539157007
# 8522  Outros_SumUp  RESTAURANTE  43547646000104    269746064
#
#                               agrupamento_nome_1
# 8339  RESTAURANTE, RESTAURANTE041946898603550308
# 8340  RESTAURANTE, RESTAURANTE041946898603550308
# 8341  RESTAURANTE, RESTAURANTE041946898603550308
# 8342  RESTAURANTE, RESTAURANTE041946898603550308
# 8343  RESTAURANTE, RESTAURANTE041946898603550308
# ...                                          ...
# 8518  RESTAURANTE, RESTAURANTE041946898603550308
# 8519  RESTAURANTE, RESTAURANTE041946898603550308
# 8520  RESTAURANTE, RESTAURANTE041946898603550308
# 8521  RESTAURANTE, RESTAURANTE041946898603550308
# 8522  RESTAURANTE, RESTAURANTE041946898603550308
#
# [177 rows x 5 columns]

# %%
show_dataframe(df, nome=nome, gid = 'group_id_idx2')#[['mmhid_merge', 'merchant_market_hierarchy_id']].value_counts()
# Out:
#         subs_asterisk                     nome_master  nome_muni  uf  \
# 1855            Ifood               RESTAURANTEYAMASU  São Paulo  SP
# 2026            Ifood                          CARLOS  São Paulo  SP
# 2027           Outros                          CARLOS  São Paulo  SP
# 2028           Outros                          CARLOS  São Paulo  SP
# 2029           Outros                          CARLOS  São Paulo  SP
# ...               ...                             ...        ...  ..
# 1305786           Ton  LANCHONETERESTAURANTEMAEEFILHO  São Paulo  SP
# 1306322           Ton                  EMPORIOCOLINAS  São Paulo  SP
# 1319152           Ton                HAYAIRESTAURANTE  São Paulo  SP
# 1321180           Ton               SBTECHINFORMATICA  São Paulo  SP
# 1321560           Ton          LANCHONETEERESTAURANTE  São Paulo  SP
#
#                  cpf cpf_brasil  qtd_cpfs  qtd_cnpjs            cnpj  \
# 1855            None       None      <NA>          1  29790794000116
# 2026     51223249808       None     49359      11723  53140292000124
# 2027     51223249808       None     49359      11723  53140292000124
# 2028     51223249808       None     49359      11723  53140292000124
# 2029     51223249808       None     49359      11723  53140292000124
# ...              ...        ...       ...        ...             ...
# 1305786  11127752855       None      <NA>       <NA>            None
# 1306322  08896698804       None      <NA>       <NA>            None
# 1319152         None       None      <NA>       <NA>  10991077000124
# 1321180  33149421845       None      <NA>       <NA>            None
# 1321560  26946089812       None      <NA>       <NA>            None
#
#         numero_inicio  ...                                 agrupamento_nome_1  \
# 1855             None  ...     RESTAURANTEYAMASU, RESTAURANTEYAMASUSHI3550308
# 2026         52561332  ...                   CARLOS23136047800, CARLOS3550308
# 2027             None  ...                   CARLOS23136047800, CARLOS3550308
# 2028             None  ...                   CARLOS23136047800, CARLOS3550308
# 2029             None  ...                   CARLOS23136047800, CARLOS3550308
# ...               ...  ...                                                ...
# 1305786          None  ...  LANCHONETERESTAURANTEMAEEFILHO, LANCHONETEREST...
# 1306322          None  ...               EMPORIOCOLINAS, EMPORIOCOLINA3550308
# 1319152          None  ...                            HAYAIRESTAURANTE3550308
# 1321180          None  ...                           SBTECHINFORMATICA3550308
# 1321560          None  ...  LANCHONETEERESTA, LANCHONETEERESTAU, LANCHONET...
#
#         _merge                                     group_id   new_id  \
# 1855      both            RESTAURANTEYAMASUSHI|São Paulo SP     1855
# 2026      both                          CARLOS|São Paulo SP     2026
# 2027      both                          CARLOS|São Paulo SP     2027
# 2028      both                          CARLOS|São Paulo SP     2028
# 2029      both                          CARLOS|São Paulo SP     2029
# ...        ...                                          ...      ...
# 1305786   both  LANCHONETERESTAURANTEMAEEFILHO|São Paulo SP  1305786
# 1306322   both                  EMPORIOCOLINAS|São Paulo SP  1306322
# 1319152   both                HAYAIRESTAURANTE|São Paulo SP  1319152
# 1321180   both               SBTECHINFORMATICA|São Paulo SP  1321180
# 1321560   both          LANCHONETEERESTAURANTE|São Paulo SP  1321560
#
#          group_id_idx1 tam_group1 group_id_idx2 tam_group2 group_id_idx3  \
# 1855               583          2        864830       1720          1605
# 2026               677         72        864830       1720          1605
# 2027               677         72        864830       1720          1605
# 2028               677         72        864830       1720          1754
# 2029               677         72        864830       1720          1755
# ...                ...        ...           ...        ...           ...
# 1305786          11481         15        864830       1720          1605
# 1306322         769177          2        864830       1720          1605
# 1319152         955801          1        864830       1720          1605
# 1321180         957525          1        864830       1720          1605
# 1321560          16155        148        864830       1720          1605
#
#         tam_group3
# 1855           128
# 2026           128
# 2027           128
# 2028             1
# 2029             3
# ...            ...
# 1305786        128
# 1306322        128
# 1319152        128
# 1321180        128
# 1321560        128
#
# [1720 rows x 28 columns]

# %%
show_dataframe(df, nome=nome, gid = 'group_id_idx3')#[['mmhid_merge', 'merchant_market_hierarchy_id']].value_counts()
# Out:
#                   subs_asterisk                     nome_master  nome_muni  \
# 1855                      Ifood               RESTAURANTEYAMASU  São Paulo
# 2026                      Ifood                          CARLOS  São Paulo
# 2027                     Outros                          CARLOS  São Paulo
# 2033                  PagSeguro                          CARLOS  São Paulo
# 2079     MercadoPago_subPagarme                          CARLOS  São Paulo
# ...                         ...                             ...        ...
# 1305786                     Ton  LANCHONETERESTAURANTEMAEEFILHO  São Paulo
# 1306322                     Ton                  EMPORIOCOLINAS  São Paulo
# 1319152                     Ton                HAYAIRESTAURANTE  São Paulo
# 1321180                     Ton               SBTECHINFORMATICA  São Paulo
# 1321560                     Ton          LANCHONETEERESTAURANTE  São Paulo
#
#          uf          cpf cpf_brasil  qtd_cpfs  qtd_cnpjs            cnpj  \
# 1855     SP         None       None      <NA>          1  29790794000116
# 2026     SP  51223249808       None     49359      11723  53140292000124
# 2027     SP  51223249808       None     49359      11723  53140292000124
# 2033     SP  51223249808       None     49359      11723  53140292000124
# 2079     SP  13416663870       None         1          0            None
# ...      ..          ...        ...       ...        ...             ...
# 1305786  SP  11127752855       None      <NA>       <NA>            None
# 1306322  SP  08896698804       None      <NA>       <NA>            None
# 1319152  SP         None       None      <NA>       <NA>  10991077000124
# 1321180  SP  33149421845       None      <NA>       <NA>            None
# 1321560  SP  26946089812       None      <NA>       <NA>            None
#
#         numero_inicio  ...                                 agrupamento_nome_1  \
# 1855             None  ...     RESTAURANTEYAMASU, RESTAURANTEYAMASUSHI3550308
# 2026         52561332  ...                   CARLOS23136047800, CARLOS3550308
# 2027             None  ...                   CARLOS23136047800, CARLOS3550308
# 2033             None  ...                   CARLOS23136047800, CARLOS3550308
# 2079             None  ...                   CARLOS23136047800, CARLOS3550308
# ...               ...  ...                                                ...
# 1305786          None  ...  LANCHONETERESTAURANTEMAEEFILHO, LANCHONETEREST...
# 1306322          None  ...               EMPORIOCOLINAS, EMPORIOCOLINA3550308
# 1319152          None  ...                            HAYAIRESTAURANTE3550308
# 1321180          None  ...                           SBTECHINFORMATICA3550308
# 1321560          None  ...  LANCHONETEERESTA, LANCHONETEERESTAU, LANCHONET...
#
#         _merge                                     group_id   new_id  \
# 1855      both            RESTAURANTEYAMASUSHI|São Paulo SP     1855
# 2026      both                          CARLOS|São Paulo SP     2026
# 2027      both                          CARLOS|São Paulo SP     2027
# 2033      both                          CARLOS|São Paulo SP     2033
# 2079      both                          CARLOS|São Paulo SP     2079
# ...        ...                                          ...      ...
# 1305786   both  LANCHONETERESTAURANTEMAEEFILHO|São Paulo SP  1305786
# 1306322   both                  EMPORIOCOLINAS|São Paulo SP  1306322
# 1319152   both                HAYAIRESTAURANTE|São Paulo SP  1319152
# 1321180   both               SBTECHINFORMATICA|São Paulo SP  1321180
# 1321560   both          LANCHONETEERESTAURANTE|São Paulo SP  1321560
#
#          group_id_idx1 tam_group1 group_id_idx2 tam_group2 group_id_idx3  \
# 1855               583          2        864830       1720          1605
# 2026               677         72        864830       1720          1605
# 2027               677         72        864830       1720          1605
# 2033               677         72        864830       1720          1605
# 2079               677         72        864830       1720          1605
# ...                ...        ...           ...        ...           ...
# 1305786          11481         15        864830       1720          1605
# 1306322         769177          2        864830       1720          1605
# 1319152         955801          1        864830       1720          1605
# 1321180         957525          1        864830       1720          1605
# 1321560          16155        148        864830       1720          1605
#
#         tam_group3
# 1855           128
# 2026           128
# 2027           128
# 2033           128
# 2079           128
# ...            ...
# 1305786        128
# 1306322        128
# 1319152        128
# 1321180        128
# 1321560        128
#
# [128 rows x 28 columns]

# %%
df4[df4['group_id']=='RESTAURANTEYAMASUSHI|São Paulo SP'][['nome_master', 'group_id', 'agrupamento_nome_1', 'mmhid_places', 'group_id_index']]
# Out:
#                  nome_master                           group_id  \
# 1855       RESTAURANTEYAMASU  RESTAURANTEYAMASUSHI|São Paulo SP
# 257737  RESTAURANTEYAMASUSHI  RESTAURANTEYAMASUSHI|São Paulo SP
#
#                                     agrupamento_nome_1 mmhid_places  \
# 1855    RESTAURANTEYAMASU, RESTAURANTEYAMASUSHI3550308  created1855
# 257737  RESTAURANTEYAMASU, RESTAURANTEYAMASUSHI3550308    505114550
#
#         group_id_index
# 1855            864830
# 257737          864830

# %%
df4[df4['mmhid_places']=='505114550'][['nome_master', 'group_id', 'agrupamento_nome_1', 'mmhid_places', 'group_id_index']]
# Out:
#                  nome_master                           group_id  \
# 8364             RESTAURANTE           RESTAURANTE|São Paulo SP
# 257737  RESTAURANTEYAMASUSHI  RESTAURANTEYAMASUSHI|São Paulo SP
#
#                                     agrupamento_nome_1 mmhid_places  \
# 8364        RESTAURANTE, RESTAURANTE041946898603550308    505114550
# 257737  RESTAURANTEYAMASU, RESTAURANTEYAMASUSHI3550308    505114550
#
#         group_id_index
# 8364            864830
# 257737          864830

# %%
df4[df4['group_id']=='RESTAURANTE|São Paulo SP'][['nome_master', 'group_id', 'agrupamento_nome_1', 'mmhid_places', 'group_id_index']]
# Out:
#       nome_master                  group_id  \
# 8339  RESTAURANTE  RESTAURANTE|São Paulo SP
# 8340  RESTAURANTE  RESTAURANTE|São Paulo SP
# 8341  RESTAURANTE  RESTAURANTE|São Paulo SP
# 8342  RESTAURANTE  RESTAURANTE|São Paulo SP
# 8343  RESTAURANTE  RESTAURANTE|São Paulo SP
# ...           ...                       ...
# 8518  RESTAURANTE  RESTAURANTE|São Paulo SP
# 8519  RESTAURANTE  RESTAURANTE|São Paulo SP
# 8520  RESTAURANTE  RESTAURANTE|São Paulo SP
# 8521  RESTAURANTE  RESTAURANTE|São Paulo SP
# 8522  RESTAURANTE  RESTAURANTE|São Paulo SP
#
#                               agrupamento_nome_1 mmhid_places  group_id_index
# 8339  RESTAURANTE, RESTAURANTE041946898603550308    647431069          864830
# 8340  RESTAURANTE, RESTAURANTE041946898603550308    815781288          864830
# 8341  RESTAURANTE, RESTAURANTE041946898603550308    866201937          864830
# 8342  RESTAURANTE, RESTAURANTE041946898603550308    799200892          864830
# 8343  RESTAURANTE, RESTAURANTE041946898603550308    763948377          864830
# ...                                          ...          ...             ...
# 8518  RESTAURANTE, RESTAURANTE041946898603550308    715575740          864830
# 8519  RESTAURANTE, RESTAURANTE041946898603550308    565315603          864830
# 8520  RESTAURANTE, RESTAURANTE041946898603550308    847270011          864830
# 8521  RESTAURANTE, RESTAURANTE041946898603550308    539157007          864830
# 8522  RESTAURANTE, RESTAURANTE041946898603550308    269746064          864830
#
# [184 rows x 5 columns]

# %%
df3['len_resultado'] = df3.groupby('group_id')['nome_master'].transform('count')

# %%
df3
# Out:
#         subs_asterisk                    nome_master  nome_muni  uf  \
# 0               SumUp                        REYTECH  São Paulo  SP
# 1               SumUp                   APPSERVIDORE  São Paulo  SP
# 2               SumUp                    JOSEWILSONP  São Paulo  SP
# 3               SumUp                      MARIAARTS  São Paulo  SP
# 4               SumUp                   CANILBUTDOGG  São Paulo  SP
# ...               ...                            ...        ...  ..
# 1334900           Ton  CLINICAODONTOLOGIADENISEFERES  São Paulo  SP
# 1334901           Ton                  POINTDOCOYOTE  São Paulo  SP
# 1334902           Ton             ANGELICADAMOTALIMA  São Paulo  SP
# 1334903           Ton         BRUNACECCHETTIESTETICA  São Paulo  SP
# 1334904           Ton              DANTILANDIARACOES  São Paulo  SP
#
#                  cpf cpf_brasil  qtd_cpfs  qtd_cnpjs            cnpj  \
# 0               None       None      <NA>          1  55288394000117
# 1               None       None      <NA>       <NA>            None
# 2        17782026830       None        26         10  20701303000149
# 3               None       None      <NA>       <NA>            None
# 4               None       None      <NA>       <NA>            None
# ...              ...        ...       ...        ...             ...
# 1334900         None       None      <NA>       <NA>  03670613000124
# 1334901  16154481870       None      <NA>       <NA>            None
# 1334902  44972567821       None      <NA>       <NA>            None
# 1334903  39824084827       None      <NA>       <NA>            None
# 1334904         None       None      <NA>       <NA>  54369975000110
#
#         numero_inicio  ...  mmhid_merge merchant_market_hierarchy_id  \
# 0                None  ...         <NA>                         <NA>
# 1                None  ...         <NA>                         <NA>
# 2                None  ...         <NA>                         <NA>
# 3                None  ...         <NA>                         <NA>
# 4                None  ...         <NA>                         <NA>
# ...               ...  ...          ...                          ...
# 1334900          None  ...         <NA>                         <NA>
# 1334901          None  ...         <NA>                         <NA>
# 1334902          None  ...         <NA>                         <NA>
# 1334903          None  ...         <NA>                         <NA>
# 1334904          None  ...         <NA>                         <NA>
#
#                                  nome_ton  inicio  \
# 0                                    None  REYTEC
# 1                                    None  APPSER
# 2                                    None  JOSEWI
# 3                                    None  MARIAA
# 4                                    None  CANILB
# ...                                   ...     ...
# 1334900  CLINICA ODONTOLOGIA DENISE FERES  CLINIC
# 1334901                   POINT DO COYOTE  POINTD
# 1334902             ANGELICA DA MOTA LIMA  ANGELI
# 1334903          BRUNA CECCHETTI ESTETICA  BRUNAC
# 1334904                DANTILANDIA RACOES  DANTIL
#
#                            grouped_names  \
# 0                              [REYTECH]
# 1                         [APPSERVIDORE]
# 2                          [JOSEWILSONP]
# 3                            [MARIAARTS]
# 4                         [CANILBUTDOGG]
# ...                                  ...
# 1334900  [CLINICAODONTOLOGIADENISEFERES]
# 1334901                  [POINTDOCOYOTE]
# 1334902             [ANGELICADAMOTALIMA]
# 1334903         [BRUNACECCHETTIESTETICA]
# 1334904              [DANTILANDIARACOES]
#
#                                         agrupamento_nome_1 _merge  \
# 0                                           REYTECH3550308   both
# 1                                      APPSERVIDORE3550308   both
# 2                     JOSEWILSONP, JOSEWILSONPEGADO3550308   both
# 3                                         MARIAARTS3550308   both
# 4                                      CANILBUTDOGG3550308   both
# ...                                                    ...    ...
# 1334900  CLINICAODONTOLOGIA, CLINICAODONTOLOGIADENISEFE...   both
# 1334901                               POINTDOCOYOTE3550308   both
# 1334902                          ANGELICADAMOTALIMA3550308   both
# 1334903                      BRUNACECCHETTIESTETICA3550308   both
# 1334904                           DANTILANDIARACOES3550308   both
#
#         group_id_index                                           group_id  \
# 0                    1                               REYTECH|São Paulo SP
# 1                    2                          APPSERVIDORE|São Paulo SP
# 2                    3                           JOSEWILSONP|São Paulo SP
# 3                    4                             MARIAARTS|São Paulo SP
# 4                    5                          CANILBUTDOGG|São Paulo SP
# ...                ...                                                ...
# 1334900         878144  CLINICAODONTOLOGICADENISEFERESLTDA|São Paulo S...
# 1334901         878145  VANDERLEIBATISTABARROS|São Paulo SP, POINTDOCO...
# 1334902         878146  ANGLICADAMOTALIMA|São Paulo SP, ANGELICADAMOTA...
# 1334903         594277  BRUNACECCHETTIMENDESDASILVA|São Paulo SP, BRUN...
# 1334904         878148  RIVANILDOCOELHODEALMEIDA|São Paulo SP, DANTILA...
#
#          len_resultado
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# ...                ...
# 1334900              2
# 1334901              2
# 1334902              2
# 1334903              3
# 1334904              2
#
# [1334905 rows x 22 columns]

# %%
df3[df3['len_resultado']>1000]['agrupamento_nome_1'].unique()
# Out:
# array(['RESTAURANTEYAMASU, RESTAURANTEYAMASUSHI3550308',
#        'CARLOS23136047800, CARLOS3550308',
#        'RESTAURANTED, RESTAURANTEDAANA, RESTAURANTEDA, RESTAURANTEDAA3550308',
#        'RESTAURANTEFRIGID, RESTAURANTEFRIGIDEIRA, RESTAURANTEFRIGIDEIR3550308',
#        'SABORNORDESTINO, SABORNORDESTI, SABORNORDESTINODALU, SABORNORDESTIN3550308',
#        'RCDESOUSA, RCDESOUSAALIMENTO, RCDESOUSAALIME3550308',
#        'RJGOMESLANCHON, RJGOMESLANCHONETEE3550308',
#        'RESTAURANTE, RESTAURANTE041946898603550308', 'PERAEACAI3550308',
#        'BARDALOIRA10152151818, BARDALOIRA3550308',
#        'MARIORESTAURANTE, MARIORESTAUR3550308',
#        'RESTAURANTEEPIZZAR, RESTAURANTEEPIZZARIAKINJOSLTDA, RESTAURANTEEPIZZARI, RESTAURANTEEPIZZ, RESTAURANTEEPIZZA, RESTAURANTEEPIZZARIA3550308',
#        'LANCHSANTAVITORIA3550308',
#        'LANCHONETEEACAIDOR, LANCHONETEEACA, LANCHONETEEACAI, LANCHONETEE, LANCHONETEEA3550308',
#        'RESTAURANTEGAL, RESTAURANTEGA, RESTAURANTEGALERI, RESTAURANTEGALERIA3550308',
#        'RESTAURANTETA, RESTAURANTET, RESTAURANTETAG, RESTAURANTETAGOS3550308',
#        'LANCHONETERESTAURANTEMAEEFILHO, LANCHONETERESTAURANTE, LANCHONETERESTAURANT, LANCHONETERESTAURAN, LANCHONETERESTAUR, LANCHONETERESTAU3550308',
#        'LANCHONETEIMP, LANCHONETEIMPERADORD, LANCHONETEIMPERADOR, LANCHONETEIMPERAD3550308',
#        'ESTRELA, ESTRELAADMPAGAMENTOS, ESTRELAA, ESTRELAADMPAGAMENTO3550308',
#        'GERALDONETODESO, GERALDONETODESOUZA3550308',
#        'SAPATARIA, SAPATARIAALEGRIA3550308',
#        'SABORMINEIROE, SABORMINEIRO3550308',
#        'ENCONTRODEMI, ENCONTRODEMINAS3550308',
#        'RESTAURANTEV, RESTAURANTEVAIQUEC, RESTAURANTEVAIQUECO3550308',
#        'RESTAURANTELANCHONET, RESTAURANTELANCHONE, RESTAURANTELANCHONETEDOSANJOS, RESTAURANTELANCHONETE, RESTAURANTELANCHO, RESTAURANTELAN, RESTAURANTELANCH3550308',
#        'RESTAURANTERAGONEZI, RESTAURANTERAGONEZIL, RESTAURANTERA, RESTAURANTER, RESTAURANTERAGONE3550308',
#        'LANCHONETEERESTA, LANCHONETEERESTAU, LANCHONETEERESTAUR, LANCHONETEERESTAURANTECHAPAQUENTE, LANCHONETEEREST, LANCHONETEERESTAURANTE, LANCHONETEER, LANCHONETEERES, LANCHONETEERESTAURA, LANCHONETEERESTAURAN3550308',
#        'LANCHONETEEALIME, LANCHONETEEALIMENTO3550308',
#        'RESTAURANTECHURRASCAR, RESTAURANTECHURR, RESTAURANTECHURRASC, RESTAURANTECHURRAS3550308',
#        'LANCHVERDEEVERM3550308',
#        'RESTAURANTEECHURR, RESTAURANTEECHURRAS, RESTAURANTEECHURRASC, RESTAURANTEECHUR3550308',
#        'LANCHESESALGA, LANCHESESALG, LANCHESESALGADOS, LANCHESESALGADOSDANALVA3550308',
#        'LANCHONETEEPIZZAR, LANCHONETEEPIZZARIAAR, LANCHONETEEPIZZARIA, LANCHONETEEPIZ, LANCHONETEEPIZZA3550308',
#        'REGIANESANTO, REGIANESANTOSABI, REGIANESANTOSABILIO, REGIANESANTOS3550308',
#        'RESTAURANTEELANC, RESTAURANTEELANCH, RESTAURANTEELANCHB3550308',
#        'CREUZADEFATIMAMOREI, CREUZADEFATIMAM, CREUZADEFATIMAMORE3550308',
#        'PRINCESADESTOAMARO3550308',
#        'ADISLENEARAUJOPE, ADISLENEARAUJOPECCOR, ADISLENEARAUJOPECCO3550308',
#        'LUCINEIDESILVASANTA, LUCINEIDESILVASANTAN3550308',
#        'RESTALTODOPARI3550308', 'BOTECOTAMANDARE, BOTECOTAMANDA3550308',
#        'RESTAURANTEED, RESTAURANTEEDELICAT, RESTAURANTEEDELI3550308',
#        'RESTAURANTEELANCHON, RESTAURANTEELANCHONETEDUTRAS, RESTAURANTEELANCHONET, RESTAURANTEELANCHONE3550308',
#        'LUELEO3550308',
#        'LANCHONETEESTRELADA, LANCHONETEESTRELA, LANCHONETEESTR3550308',
#        'BRASABRAS3550308', 'RESTAURANTEGOMES, RESTAURANTEGOMESEMA3550308',
#        'LANCHONETEECHO, LANCHONETEECHOPERIA3550308',
#        'LANCHONETENOVACISPER3550308', 'RESTAURANTEFAZENDINHA3550308',
#        'LANCHONETETRADICAODO3550308',
#        'LANCHONETEPRINCESIN, LANCHONETEPRINCESINHA, LANCHONETEPRINCESINH3550308',
#        'LANCHONETECAMPOLIMPO3550308', 'RESTAURANTEGAUCHO3550308',
#        'PAUBRASIL, PAUBRASILBEACHCLUB3550308',
#        'LANCHONETEEMERCEARIA, LANCHONETEEMERCEARI, LANCHONETEEMERCEA3550308',
#        'NOVABBJ3550308',
#        'LANCHONETETRADICAOBE, LANCHONETETRADICAO3550308',
#        'RESTAURANTEJAMAICA, RESTAURANTEJAMAIC3550308', 'DJBAR3550308',
#        'CARLOSALVESFERREIRA3550308',
#        'LANCHONETEVAREJINHOL, LANCHONETEVAREJINHO3550308',
#        'RESTAURANTEREPUBLICA3550308',
#        'RESTAURANTERIOSANTO, RESTAURANTERIOS3550308',
#        'RESTAURANTLANCHONET3550308', 'SABORESDOMORUMBI3550308',
#        'LANCHONETEACONCHEGOM, LANCHONETEACONCHEGO, LANCHONETEACO, LANCHONETEACON3550308',
#        'DMCOMERCIOEREFEICO3550308', 'NITEROIBRA3550308',
#        'LANCHONETE01354592000102, LANCHONETE3550308',
#        'TATIANAALCANTARA, TATIANAALCANTARADAS3550308',
#        'PADROEIRARESTAURANTE, PADROEIRA3550308', 'SABOREMFAMILIA3550308',
#        'RESTAURANTEDOBAIX, RESTAURANTEDOBAIXINH3550308',
#        'LANCHONETEESTRELADO3550308',
#        'RESTAURANTEE, RESTAURANTEEADEGA, RESTAURANTEEADEGAC, RESTAURANTEEADEGACE3550308',
#        'LANCHONETEEPAS, LANCHONETEEPASTELAR, LANCHONETEEPASTELARI, LANCHONETEEPASTE, LANCHONETEEPASTEL3550308',
#        'RESTAURANTEDOALEMAO, RESTAURANTEDO3550308',
#        'RESTAURANTEDAERIKA3550308', 'LANCHONETEPAUMANDADO3550308',
#        'SABORFAMILIA, SABORFAMILIAR, SABORF, SABORFAMILIARESTA3550308',
#        'LANCHERESTMANGA3550308',
#        'RESTAURANTETRASMONTAN, RESTAURANTETRASMONTA3550308',
#        'FRANCISCOWESLLEYARAU, FRANCISCOWESLLEY3550308',
#        'IMPERMEABILIZADORAI3550308', 'PIPHININDOURO3550308',
#        'LANCHONETEQDELICI3550308', 'OPCAOLANCHES3550308',
#        'RESTAURANTECOUTINHO3550308', 'LANCHRAINHAMARCOLINA3550308',
#        'KISABORBARERESTAUR, KISABOR, KISABORBARERES3550308',
#        'LANCHONETEARTEMINEI, LANCHONETEARTE, LANCHONETEARTEMINEIR3550308',
#        'JARDIMOLIMPIA3550308', 'LANCHONETEFASELY3550308',
#        'ROGERIOSILVABISPO, ROGERIOSILVA3550308',
#        'RESTAURANTEPAPAGA, RESTAURANTEPAPAGAIU3550308',
#        'LANCHONETEOPCAO3550308',
#        'TATIANEMARINHODOS, TATIANEMARINHODOSP, TATIANEMARINHODOSPA3550308',
#        'CHARMEDECONGONHAS3550308', 'CLODOALDORESTAURANT3550308',
#        'CLEBERDOSANJOS, CLEBERDOSANJOSBATIS3550308',
#        'LANCHONETEBUCHOQUEB3550308', 'LANCHONETENOVACAMBUC3550308',
#        'LANCHONETEACOPIAR, LANCHONETEACOPIARAGL, LANCHONETEACOPIARA3550308',
#        'LOJAOARTISTICO3550308', 'VALETSSLANCHES3550308',
#        'LANCHONETEAPETITENO, LANCHONETEAP, LANCHONETEAPETITE, LANCHONETEAPETITENOR3550308',
#        'LANCHONETETANZINHO3550308',
#        'CARLOSALBERTOFERREIRACAVALCANTE, CARLOSALBERTOFERREIR, CARLOSALBERTOFERR, CARLOSALBERTOFERREIRA3550308',
#        'RESTAURANTESABOREAR, RESTAURANTESABORE3550308',
#        'RESTAURANTESENSACAO3550308', 'RESTAURANTEEMERCEARI3550308',
#        'RESTAURANTEFORTUNATOS3550308', 'PANIFICFLORDOPARAIS3550308',
#        'MBNADKARNISERVICOS3550308',
#        'RECANTODA, RECANTODAACLIMACAO3550308',
#        'LANCHONETEDOCA, LANCHONETEDOCAMILO, LANCHONETEDOCAMIL3550308',
#        'RESTAURANTEPROFESSOR3550308',
#        'MERCEARIAFAK, MERCEARIAFAKLTDAME3550308',
#        'RESTAURANTEPERCIANI3550308', 'LANCHVAREJINHO3550308',
#        'PIZZARIAMISTERGERA, PIZZARIAMISTER3550308',
#        'IZAQUEURODRIGUESCAV3550308', 'RESTAURANTEELMA3550308',
#        'BBJRIOBRANCO3550308', 'RESTAURANTEREQUINTEG3550308',
#        'LUARTRESTAURANTEEPI3550308', 'CHARMEDAPRACA3550308',
#        'POINTMOEMA3550308', 'LANCHRESTACAI3550308',
#        'RESTAURANTEECHOPERIAPI, RESTAURANTEECH, RESTAURANTEECHOP, RESTAURANTEECHOPERI, RESTAURANTEECHOPERIA3550308',
#        'RESTAURANTEBUDEGAS, RESTAURANTEBU3550308',
#        'PADOKABAIAOPARENTE, PADOKA3550308',
#        'LANCHONETEDOISIRMAOS, LANCHONETEDOISIRMAO3550308',
#        'LANCHONETECONQUISTA3550308',
#        'RICOSABOR, RICOSABORALIMENTOSL3550308', 'BIGMULTI3550308',
#        'THIAGORIBEIRODE, THIAGORIBEIRODEALCA3550308',
#        'LANCHONETERIACHODOCE, LANCHONETERIACHODOC3550308',
#        'RESTAURANTETRAJANOSI, RESTAURANTETRAJANO3550308',
#        'FLORDOSACOMA3550308',
#        'LANCHONETETOMCAT, LANCHONETETOMCATLTD3550308',
#        'LANCHONETEJECLTDA3550308', 'RESTAURANTECRUZEIRO3550308',
#        'RESTAURANTEMEAIPE, RESTAURANTEME3550308',
#        'KISABORPIZZARIA, KISABORPIZZARIALTDA3550308',
#        'RESTAURANTECORDEIROL3550308',
#        'JOAOVICTORDEALMEIDA, JOAOVICTORDE3550308',
#        'RESTAURANTEALMIRANTE3550308',
#        'LANCHONETEJA, LANCHONETEJABAQUARAA3550308',
#        'RESTAURANTESILVAS3550308',
#        'LANCHONETEDOMINEIRO, LANCHONETEDOMINEI3550308',
#        'RESTAURANTECAM, RESTAURANTECAMANDA3550308',
#        'NOVASKINA, NOVASKINABAR3550308', 'RESTAURANTEESTACAOSA3550308',
#        'RESTAURANTETERRAMINE3550308', 'RESTAURANTEMANOSJR3550308',
#        'MANGAEACAI3550308', 'RESTAURANTEORIENTALS3550308',
#        'PERPETUADASILVASOA3550308', 'BARESORVETERIAGIBRA3550308',
#        'ESTACAODAVILLA, ESTACAODAVILLALTDA3550308',
#        'RESTAURANTESANTAGULA3550308', 'VILLASCHICKE, VILLASCHIC3550308',
#        'RESTAURANTEMANAH3550308',
#        'LANCHONETEPRALADEB, LANCHONETEPRALADE3550308',
#        'JFMOURABARLANCH3550308', 'BONEORGANIZACAODEEV3550308',
#        'RESTAURANTEELANCHES3550308', 'LANCHONETEMACEDO3550308',
#        'CANTINHODACOTOVIA3550308', 'CHARMEDEHIGIENOPOLIS3550308',
#        'RESTAURANTEMOLINA3550308', 'LANCHONETECHAPECO3550308',
#        'ESTRELADALINS3550308', 'FLORDAVILA, FLORDAVILABUARQUE3550308',
#        'PORTALDACACHOEIRINH3550308', 'BARLANCHONETEALVORAD3550308',
#        'LANCESTRELADAPENHA3550308', 'EDUARDOLANCHONETE3550308',
#        'RESTAURANTEDOPRIMO3550308', 'RIVELINOHENZME3550308',
#        'RESTAURANTEDOCE, RESTAURANTEDOCEAR, RESTAURANTEDOCEARA3550308',
#        'LANCHCHARMOSAPARI3550308',
#        'RESTAURANTEORIENTALD, RESTAURANTEORIENT, RESTAURANTEORIENTAL3550308',
#        'RESTAURANTEFAMILI, RESTAURANTEFAM, RESTAURANTEFAMILIA, RESTAURANTEFAMILIAAL3550308',
#        'LANCHONETESILVA, LANCHONETESILVAS3550308',
#        'PAUBRASILMOLDURAS3550308', 'RESTELANCHSTYLLUS3550308',
#        'LANCHONETEDOCIGANO3550308', 'ESTRELADESANTANA3550308',
#        'RESTESTACAOSTACRUZ3550308',
#        'CARLOSFERR, CARLOSFERRAGENS, CARLOSFERRAGENSEFER3550308',
#        'LANCHONETEESTRELADE3550308', 'RESTFAZENDINHA3550308',
#        'NEVESEBRITORESTAUR3550308', 'RESTAURIRMABETTY3550308',
#        'RESTAURANTEEUC, RESTAURANTEEUCALIPT, RESTAURANTEEUCALIPTO3550308',
#        'FINISTERRE3550308', 'GPBRINDUSTRIAECOMRE3550308',
#        'ESTRELADOGRIMALDE3550308', 'COLORMATIC3550308',
#        'MADUCARESTAURANTE3550308',
#        'ESTACAODAVILLAR, ESTACAODAVILLARESTA3550308',
#        'CHARMED, CHARMEDABARRA3550308',
#        'LANCHONETEPAU, LANCHONETEPAUBRASI3550308',
#        'LANCHONETEESTRELASAO3550308', 'RESTLANCHRSAOLUIS3550308',
#        'SAOGABRIELLANCHONETE3550308', 'PARATYBRASIL3550308',
#        'LANCHONETEESALGADOS, LANCHONETEES, LANCHONETEESALGA3550308',
#        'LANCHONETEPRIM, LANCHONETEPRIMEBOX, LANCHONETEPRI3550308',
#        'DOMLORENZO, DOMLORENZOPENHA3550308', 'BARELANCHONETEQUATA3550308',
#        'RESTEPIZZDRACENA3550308', 'DUPARAIBA3550308',
#        'CANBUCHOQUEBRADO3550308', 'BARDOSCAMILOS3550308',
#        'TRADICAOCONCEICAO3550308', 'LANCHONETETRADICAODE3550308',
#        'LANCHESBAROLIVEIRAL3550308', 'LANCHONETERESTADEGA3550308',
#        'LANCHONETEBBJ3550308', 'LAPECAFERESTAURANTE3550308',
#        'RESTAURANTEDONAJU, RESTAURANTEDONAJUJU3550308',
#        'CANTINHODAGIO3550308', 'GELEIAS, GELEIASGENI3550308',
#        'CHICKENLAPA3550308', 'NOVAVENCESLAUBRAS3550308',
#        'LANCHONETEMORUMBILTD3550308', 'ELITEDOJABAQUARA3550308',
#        'LANCHONETETESOURODA3550308', 'MERCEARIABADU3550308',
#        'ESTRELAPARADA3550308', 'PRESILHADALAPA3550308',
#        'RESTELANCHCRUZEIRO3550308', 'RESTAURANTEDAVILLE3550308',
#        'SPEEDLINEWIFI3550308', 'DVILLERESTAURANTE3550308',
#        'PIZZARIAREIDOBARAO, PIZZARIAREIDO3550308',
#        'LANCHONETEEE, LANCHONETEEEMPORIO3550308',
#        'EMVIANARESTAURANT3550308', 'GUBANCA3550308',
#        'LANCHONETENOVAEST, LANCHONETENOVAESTOR3550308',
#        'CHURRASCOTEMP, CHURRASCOTEMPEIROGOI3550308',
#        'LINOCOUTINHO3550308', 'COPABRASIL3550308',
#        'RESTAURANTECOMIDALE3550308', 'RESTAURANTELABOCCA3550308',
#        'FRANCISCOBATISTADES3550308', 'RESTAURANTEEUCLIDENCE3550308',
#        'ESTRELADAJULIO3550308',
#        'YASMINFIGUEREDOSANTOS, YASMINFIGUER3550308',
#        'EDSONDEALMEIDA, EDSONDEALMEIDABONFI, EDSONDE3550308',
#        'CARLINHOSACESS, CARLINHOS3550308',
#        'EMBAIXADORAMANEQUINS, EMBAIXADOR3550308',
#        'LANCHONETEEBAR, LANCHONETEEBARCELOS3550308',
#        'LANCHONETEDOA, LANCHONETEDO, LANCHONETEDOAB3550308',
#        'AADEOLIVEIRA3550308',
#        'RESTAURANTECABANA, RESTAURANTECA, RESTAURANTEC, RESTAURANTECAB3550308',
#        'CANTODACOTOVIA3550308', 'FLORESTAGRILL3550308',
#        'LANCHONETEERESTDO3550308', 'RISTORINE3550308',
#        'ADEVAIRDOMINGUES3550308',
#        'RESTAURANTERICO, RESTAURANTERICONCITO3550308',
#        'LANCHONETEEMPERIO3550308', 'JORGEMAUROCORSI3550308',
#        'RESTAURANTEMILANI, RESTAURANTEMIL3550308',
#        'LANCHONETEERJOAO3550308',
#        'RESTAURANTEDOP, RESTAURANTEDOPARAIBA3550308',
#        'RESTAURANTEGEPETO3550308', 'MERCADOBIXIGA3550308',
#        'RESTAURANTETRE, RESTAURANTETRESCORACO, RESTAURANTETRESCO3550308',
#        'RESTAURANTEREN3550308',
#        'LANCHONETECABANA, LANCHONETECA, LANCHONETECABANAD3550308',
#        'RESTAURANTEPRI, RESTAURANTEPRIMAVERA, RESTAURANTEPRIMAV3550308',
#        'COSTAAZUL3550308', 'RESTAURANTECAR, RESTAURANTECARIOCA3550308',
#        'FLORDOPARAISO3550308', 'EMPORIOCOLINAS, EMPORIOCOLINA3550308',
#        'LANCHONETEVAIQUECO3550308', 'ESTACAOAZUL3550308',
#        'RESTAURANTEBANQUETE3550308', 'RESTAURANTBOMGOSTO3550308',
#        'BARRESTSABORDOSU3550308', 'LANCHPEIZHENGPOO3550308',
#        'RESTAURANTECORACOES, RESTAURANTECOR3550308',
#        'RESTAURANTDIPLOMATA3550308', 'RESTAURANTEDONADOSA3550308',
#        'RESTAURANTENIRAI3550308', 'LANCHNOVAESTORIL3550308',
#        'RESTAURANTEDALOIRA3550308', 'RESTAURANTESAGRADOAL3550308',
#        'ENDEOLIVEIRAEMPREIT3550308', 'TAMAKIPADARIAELANCH3550308',
#        'LANCHONETESTRELA3550308', 'IBITIRAMABURGER3550308',
#        'RESTELANCPRATOBRAS3550308', 'NAGAREBOSHI3550308',
#        'SABORDESANTANAPJ3550308', 'LANCHONETEBASILIOJAF3550308',
#        'ITABAPOAMA3550308', 'LANMANGAEACAI3550308',
#        'LANCHONETERUMOAOSOL3550308', 'MIRALAR3550308',
#        'ORQUIDEASMOTEL3550308', 'LANCHONETESILVINH3550308',
#        'DARIOTERUELRAMOS3550308', 'JEFFERSONDOSANJOSSILVA3550308',
#        'EDINALVARODRIGUESDASILVA3550308', 'DENISETEIXEIRAFERREIRA3550308',
#        'JOELMAMARIANORODRIGUES3550308', 'ALDADASILVAROCHA3550308',
#        'CELINACLEMENTEDACRUZ3550308', 'FRANCISCOJOSIMARDEMELO3550308',
#        'THIAGOMARTINSDEMELO3550308', 'DIVINOVIEIRADASILVA3550308',
#        'HAYAIRESTAURANTE3550308', 'SBTECHINFORMATICA3550308'],
#       dtype=object)

# %%
df3
# Out:
#         subs_asterisk                    nome_master  nome_muni  uf  \
# 0               SumUp                        REYTECH  São Paulo  SP
# 1               SumUp                   APPSERVIDORE  São Paulo  SP
# 2               SumUp                    JOSEWILSONP  São Paulo  SP
# 3               SumUp                      MARIAARTS  São Paulo  SP
# 4               SumUp                   CANILBUTDOGG  São Paulo  SP
# ...               ...                            ...        ...  ..
# 1334900           Ton  CLINICAODONTOLOGIADENISEFERES  São Paulo  SP
# 1334901           Ton                  POINTDOCOYOTE  São Paulo  SP
# 1334902           Ton             ANGELICADAMOTALIMA  São Paulo  SP
# 1334903           Ton         BRUNACECCHETTIESTETICA  São Paulo  SP
# 1334904           Ton              DANTILANDIARACOES  São Paulo  SP
#
#                  cpf cpf_brasil  qtd_cpfs  qtd_cnpjs            cnpj  \
# 0               None       None      <NA>          1  55288394000117
# 1               None       None      <NA>       <NA>            None
# 2        17782026830       None        26         10  20701303000149
# 3               None       None      <NA>       <NA>            None
# 4               None       None      <NA>       <NA>            None
# ...              ...        ...       ...        ...             ...
# 1334900         None       None      <NA>       <NA>  03670613000124
# 1334901  16154481870       None      <NA>       <NA>            None
# 1334902  44972567821       None      <NA>       <NA>            None
# 1334903  39824084827       None      <NA>       <NA>            None
# 1334904         None       None      <NA>       <NA>  54369975000110
#
#         numero_inicio  ...  merchant_tax_id mmhid_merge  \
# 0                None  ...             None        <NA>
# 1                None  ...             None        <NA>
# 2                None  ...             None        <NA>
# 3                None  ...             None        <NA>
# 4                None  ...             None        <NA>
# ...               ...  ...              ...         ...
# 1334900          None  ...             None        <NA>
# 1334901          None  ...             None        <NA>
# 1334902          None  ...             None        <NA>
# 1334903          None  ...             None        <NA>
# 1334904          None  ...             None        <NA>
#
#          merchant_market_hierarchy_id                          nome_ton  \
# 0                                <NA>                              None
# 1                                <NA>                              None
# 2                                <NA>                              None
# 3                                <NA>                              None
# 4                                <NA>                              None
# ...                               ...                               ...
# 1334900                          <NA>  CLINICA ODONTOLOGIA DENISE FERES
# 1334901                          <NA>                   POINT DO COYOTE
# 1334902                          <NA>             ANGELICA DA MOTA LIMA
# 1334903                          <NA>          BRUNA CECCHETTI ESTETICA
# 1334904                          <NA>                DANTILANDIA RACOES
#
#          inicio                    grouped_names  \
# 0        REYTEC                        [REYTECH]
# 1        APPSER                   [APPSERVIDORE]
# 2        JOSEWI                    [JOSEWILSONP]
# 3        MARIAA                      [MARIAARTS]
# 4        CANILB                   [CANILBUTDOGG]
# ...         ...                              ...
# 1334900  CLINIC  [CLINICAODONTOLOGIADENISEFERES]
# 1334901  POINTD                  [POINTDOCOYOTE]
# 1334902  ANGELI             [ANGELICADAMOTALIMA]
# 1334903  BRUNAC         [BRUNACECCHETTIESTETICA]
# 1334904  DANTIL              [DANTILANDIARACOES]
#
#                                         agrupamento_nome_1 _merge  \
# 0                                           REYTECH3550308   both
# 1                                      APPSERVIDORE3550308   both
# 2                     JOSEWILSONP, JOSEWILSONPEGADO3550308   both
# 3                                         MARIAARTS3550308   both
# 4                                      CANILBUTDOGG3550308   both
# ...                                                    ...    ...
# 1334900  CLINICAODONTOLOGIA, CLINICAODONTOLOGIADENISEFE...   both
# 1334901                               POINTDOCOYOTE3550308   both
# 1334902                          ANGELICADAMOTALIMA3550308   both
# 1334903                      BRUNACECCHETTIESTETICA3550308   both
# 1334904                           DANTILANDIARACOES3550308   both
#
#         group_id_index                                           group_id
# 0                    1                               REYTECH|São Paulo SP
# 1                    2                          APPSERVIDORE|São Paulo SP
# 2                    3                           JOSEWILSONP|São Paulo SP
# 3                    4                             MARIAARTS|São Paulo SP
# 4                    5                          CANILBUTDOGG|São Paulo SP
# ...                ...                                                ...
# 1334900         878144  CLINICAODONTOLOGICADENISEFERESLTDA|São Paulo S...
# 1334901         878145  VANDERLEIBATISTABARROS|São Paulo SP, POINTDOCO...
# 1334902         878146  ANGLICADAMOTALIMA|São Paulo SP, ANGELICADAMOTA...
# 1334903         594277  BRUNACECCHETTIMENDESDASILVA|São Paulo SP, BRUN...
# 1334904         878148  RIVANILDOCOELHODEALMEIDA|São Paulo SP, DANTILA...
#
# [1334905 rows x 21 columns]

# %%
df2 = pd.read_parquet('data/nomes_agrupados/part_3550308.parquet')
df2['len_resultado'] = df2.groupby(['agrupamento_nome_1'])['nome_master'].transform('count')
df2
# Out:
#                   nome_master  inicio  cod_muni         resultado_names  \
# 0                                       3550308                      []
# 1                        AAAA    AAAA   3550308                  [AAAA]
# 2                AAAAAAAAAAAA  AAAAAA   3550308          [AAAAAAAAAAAA]
# 3           AAAAAAAAAAOKINAWA  AAAAAA   3550308     [AAAAAAAAAAOKINAWA]
# 4               AAAAAADOMONGE  AAAAAA   3550308         [AAAAAADOMONGE]
# ...                       ...     ...       ...                     ...
# 1095648  ZZDISTRIBUIDORADEGLP  ZZDIST   3550308  [ZZDISTRIBUIDORADEGLP]
# 1095649               ZZJOIAS  ZZJOIA   3550308               [ZZJOIAS]
# 1095650             ZZMATPARA  ZZMATP   3550308             [ZZMATPARA]
# 1095651     ZZNSHOESCALCADOSE  ZZNSHO   3550308     [ZZNSHOESCALCADOSE]
# 1095652    ZZOSHOESCALCADOSEA  ZZOSHO   3550308    [ZZOSHOESCALCADOSEA]
#
#            agrupamento_nome_1  len_resultado
# 0                                          1
# 1                        AAAA              1
# 2                AAAAAAAAAAAA              1
# 3           AAAAAAAAAAOKINAWA              1
# 4               AAAAAADOMONGE              1
# ...                       ...            ...
# 1095648  ZZDISTRIBUIDORADEGLP              1
# 1095649               ZZJOIAS              1
# 1095650             ZZMATPARA              1
# 1095651     ZZNSHOESCALCADOSE              1
# 1095652    ZZOSHOESCALCADOSEA              1
#
# [1095653 rows x 6 columns]

# %%
df2.sort_values('len_resultado')
# Out:
#                  nome_master  inicio  cod_muni  \
# 0                                      3550308
# 663321   MARCELORAYMUNDODEOL  MARCEL   3550308
# 663322        MARCELOREBEQUI  MARCEL   3550308
# 663323        MARCELOREGIANI  MARCEL   3550308
# 663326  MARCELOREGISFERREIRA  MARCEL   3550308
# ...                      ...     ...       ...
# 700533            MATERIALDE  MATERI   3550308
# 700534           MATERIALDEC  MATERI   3550308
# 700535          MATERIALDECO  MATERI   3550308
# 700537        MATERIALDECONS  MATERI   3550308
# 586226  LANCHONETEERESTAURAN  LANCHO   3550308
#
#                                           resultado_names  \
# 0                                                      []
# 663321                              [MARCELORAYMUNDODEOL]
# 663322                                   [MARCELOREBEQUI]
# 663323                                   [MARCELOREGIANI]
# 663326                             [MARCELOREGISFERREIRA]
# ...                                                   ...
# 700533  [MATERIALDEC, MATERIALDECONSTRUCA, MATERIALDE,...
# 700534  [MATERIALDEC, MATERIALDECONSTRUCA, MATERIALDE,...
# 700535  [MATERIALDEC, MATERIALDECONSTRUCA, MATERIALDE,...
# 700537  [MATERIALDEC, MATERIALDECONSTRUCA, MATERIALDE,...
# 586226  [LANCHONETEERESTA, LANCHONETEERESTAU, LANCHONE...
#
#                                        agrupamento_nome_1  len_resultado
# 0                                                                      1
# 663321                                MARCELORAYMUNDODEOL              1
# 663322                                     MARCELOREBEQUI              1
# 663323                                     MARCELOREGIANI              1
# 663326                               MARCELOREGISFERREIRA              1
# ...                                                   ...            ...
# 700533  MATERIALDEC, MATERIALDECONSTRUCAO01488093598, ...             10
# 700534  MATERIALDEC, MATERIALDECONSTRUCAO01488093598, ...             10
# 700535  MATERIALDEC, MATERIALDECONSTRUCAO01488093598, ...             10
# 700537  MATERIALDEC, MATERIALDECONSTRUCAO01488093598, ...             10
# 586226  LANCHONETEERESTA, LANCHONETEERESTAU, LANCHONET...             10
#
# [1095653 rows x 6 columns]

# %%
df2[df2['agrupamento_nome_1']=='CLAUDIAAPARECIDATANI']
# Out:
#                  nome_master  inicio  cod_muni         resultado_names  \
# 204942  CLAUDIAAPARECIDATANI  CLAUDI   3550308  [CLAUDIAAPARECIDATANI]
#
#           agrupamento_nome_1  len_resultado
# 204942  CLAUDIAAPARECIDATANI            486

# %%
df
# Out:
#         subs_asterisk                    nome_master  nome_muni  uf  \
# 0               SumUp                        REYTECH  São Paulo  SP
# 1               SumUp                   APPSERVIDORE  São Paulo  SP
# 2               SumUp                    JOSEWILSONP  São Paulo  SP
# 3               SumUp                      MARIAARTS  São Paulo  SP
# 4               SumUp                   CANILBUTDOGG  São Paulo  SP
# ...               ...                            ...        ...  ..
# 1334900           Ton  CLINICAODONTOLOGIADENISEFERES  São Paulo  SP
# 1334901           Ton                  POINTDOCOYOTE  São Paulo  SP
# 1334902           Ton             ANGELICADAMOTALIMA  São Paulo  SP
# 1334903           Ton         BRUNACECCHETTIESTETICA  São Paulo  SP
# 1334904           Ton              DANTILANDIARACOES  São Paulo  SP
#
#                  cpf cpf_brasil  qtd_cpfs  qtd_cnpjs            cnpj  \
# 0               None       None      <NA>          1  55288394000117
# 1               None       None      <NA>       <NA>            None
# 2        17782026830       None        26         10  20701303000149
# 3               None       None      <NA>       <NA>            None
# 4               None       None      <NA>       <NA>            None
# ...              ...        ...       ...        ...             ...
# 1334900         None       None      <NA>       <NA>  03670613000124
# 1334901  16154481870       None      <NA>       <NA>            None
# 1334902  44972567821       None      <NA>       <NA>            None
# 1334903  39824084827       None      <NA>       <NA>            None
# 1334904         None       None      <NA>       <NA>  54369975000110
#
#         numero_inicio  cod_muni merchant_tax_id  mmhid_merge  \
# 0                None   3550308            None         <NA>
# 1                None   3550308            None         <NA>
# 2                None   3550308            None         <NA>
# 3                None   3550308            None         <NA>
# 4                None   3550308            None         <NA>
# ...               ...       ...             ...          ...
# 1334900          None   3550308            None         <NA>
# 1334901          None   3550308            None         <NA>
# 1334902          None   3550308            None         <NA>
# 1334903          None   3550308            None         <NA>
# 1334904          None   3550308            None         <NA>
#
#          merchant_market_hierarchy_id     id_ton  \
# 0                                <NA>        NaN
# 1                                <NA>        NaN
# 2                                <NA>        NaN
# 3                                <NA>        NaN
# 4                                <NA>        NaN
# ...                               ...        ...
# 1334900                          <NA>  1818529.0
# 1334901                          <NA>  1818530.0
# 1334902                          <NA>  1818554.0
# 1334903                          <NA>  1818555.0
# 1334904                          <NA>  1818566.0
#
#                                  nome_ton  inicio  \
# 0                                    None  REYTEC
# 1                                    None  APPSER
# 2                                    None  JOSEWI
# 3                                    None  MARIAA
# 4                                    None  CANILB
# ...                                   ...     ...
# 1334900  CLINICA ODONTOLOGIA DENISE FERES  CLINIC
# 1334901                   POINT DO COYOTE  POINTD
# 1334902             ANGELICA DA MOTA LIMA  ANGELI
# 1334903          BRUNA CECCHETTI ESTETICA  BRUNAC
# 1334904                DANTILANDIA RACOES  DANTIL
#
#                          resultado_names  \
# 0                              [REYTECH]
# 1                         [APPSERVIDORE]
# 2                          [JOSEWILSONP]
# 3                            [MARIAARTS]
# 4                         [CANILBUTDOGG]
# ...                                  ...
# 1334900  [CLINICAODONTOLOGIADENISEFERES]
# 1334901                  [POINTDOCOYOTE]
# 1334902             [ANGELICADAMOTALIMA]
# 1334903         [BRUNACECCHETTIESTETICA]
# 1334904              [DANTILANDIARACOES]
#
#                                         agrupamento_nome_1 _merge
# 0                                           REYTECH3550308   both
# 1                                      APPSERVIDORE3550308   both
# 2                     JOSEWILSONP, JOSEWILSONPEGADO3550308   both
# 3                                         MARIAARTS3550308   both
# 4                                      CANILBUTDOGG3550308   both
# ...                                                    ...    ...
# 1334900  CLINICAODONTOLOGIA, CLINICAODONTOLOGIADENISEFE...   both
# 1334901                               POINTDOCOYOTE3550308   both
# 1334902                          ANGELICADAMOTALIMA3550308   both
# 1334903                      BRUNACECCHETTIESTETICA3550308   both
# 1334904                           DANTILANDIARACOES3550308   both
#
# [1334905 rows x 20 columns]

# %%
df['len_resultado'] = df.groupby(['agrupamento_nome_1'])['nome_master'].transform('count')

# %%
df.sort_values('len_resultado')
# Out:
#        subs_asterisk        nome_master  nome_muni  uf          cpf  \
# 0              SumUp            REYTECH  São Paulo  SP         None
# 831357   Outros_Pags             ABXGKS  São Paulo  SP         None
# 831358   Outros_Pags  CRISTIANBARBOSADE  São Paulo  SP         None
# 831359   Outros_Pags        JACBOUTIQUE  São Paulo  SP         None
# 831360   Outros_Pags  ROSIMARDEJESUSDOS  São Paulo  SP  32804434826
# ...              ...                ...        ...  ..          ...
# 204950   Outros_Pags     MARIAAPARECIDA  São Paulo  SP  32646176848
# 205171   Outros_Pags     MARIAAPARECIDA  São Paulo  SP  32646176848
# 205170   Outros_Pags     MARIAAPARECIDA  São Paulo  SP  32646176848
# 205175   Outros_Pags     MARIAAPARECIDA  São Paulo  SP  32646176848
# 205343   Outros_Pags     MARIAAPARECIDA  São Paulo  SP  32646176848
#
#        cpf_brasil  qtd_cpfs  qtd_cnpjs            cnpj numero_inicio  ...  \
# 0            None      <NA>          1  55288394000117          None  ...
# 831357       None      <NA>       <NA>            None          None  ...
# 831358       None      <NA>       <NA>            None          None  ...
# 831359       None      <NA>       <NA>            None          None  ...
# 831360       None         1       <NA>            None          None  ...
# ...           ...       ...        ...             ...           ...  ...
# 204950       None     14261       2771  22971232000120          None  ...
# 205171       None     14261       2771  22971232000120          None  ...
# 205170       None     14261       2771  22971232000120          None  ...
# 205175       None     14261       2771  22971232000120          None  ...
# 205343       None     14261       2771  22971232000120          None  ...
#
#         merchant_tax_id mmhid_merge  merchant_market_hierarchy_id  id_ton  \
# 0                  None        <NA>                          <NA>     NaN
# 831357             None        <NA>                     811272556     NaN
# 831358   39451476000184   706622354                     706622354     NaN
# 831359   49990855000104   796744485                     796744485     NaN
# 831360                    774904701                     774904701     NaN
# ...                 ...         ...                           ...     ...
# 204950                    856914648                     856914648     NaN
# 205171                    820486249                     820486249     NaN
# 205170   08561701000101   606337622                     606337622     NaN
# 205175                    644081404                     644081404     NaN
# 205343                    706471083                     706471083     NaN
#
#         nome_ton  inicio                                    resultado_names  \
# 0           None  REYTEC                                          [REYTECH]
# 831357      None  ABXGKS                                           [ABXGKS]
# 831358      None  CRISTI                                [CRISTIANBARBOSADE]
# 831359      None  JACBOU                                      [JACBOUTIQUE]
# 831360      None  ROSIMA                                [ROSIMARDEJESUSDOS]
# ...          ...     ...                                                ...
# 204950      None  MARIAA  [MARIAAPARECID, MARIAAPARECIDA, MARIAAPARE, MA...
# 205171      None  MARIAA  [MARIAAPARECID, MARIAAPARECIDA, MARIAAPARE, MA...
# 205170      None  MARIAA  [MARIAAPARECID, MARIAAPARECIDA, MARIAAPARE, MA...
# 205175      None  MARIAA  [MARIAAPARECID, MARIAAPARECIDA, MARIAAPARE, MA...
# 205343      None  MARIAA  [MARIAAPARECID, MARIAAPARECIDA, MARIAAPARE, MA...
#
#                                        agrupamento_nome_1 _merge len_resultado
# 0                                          REYTECH3550308   both             1
# 831357                                      ABXGKS3550308   both             1
# 831358                           CRISTIANBARBOSADE3550308   both             1
# 831359                                 JACBOUTIQUE3550308   both             1
# 831360                           ROSIMARDEJESUSDOS3550308   both             1
# ...                                                   ...    ...           ...
# 204950  MARIAAPARECID, MARIAAPARECIDA, MARIAAPARE, MAR...   both           486
# 205171  MARIAAPARECID, MARIAAPARECIDA, MARIAAPARE, MAR...   both           486
# 205170  MARIAAPARECID, MARIAAPARECIDA, MARIAAPARE, MAR...   both           486
# 205175  MARIAAPARECID, MARIAAPARECIDA, MARIAAPARE, MAR...   both           486
# 205343  MARIAAPARECID, MARIAAPARECIDA, MARIAAPARE, MAR...   both           486
#
# [1334905 rows x 21 columns]

# %%
df2[df2['nome_master']=='MARIAAPARECIDA']
# Out:
#            nome_master  inicio  cod_muni  \
# 674829  MARIAAPARECIDA  MARIAA   3550308
#
#                                           resultado_names  \
# 674829  [MARIAAPARECID, MARIAAPARECIDA, MARIAAPARE, MA...
#
#                                        agrupamento_nome_1  len_resultado
# 674829  MARIAAPARECID, MARIAAPARECIDA, MARIAAPARE, MAR...              5
